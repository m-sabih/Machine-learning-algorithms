# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import math
from PIL import Image

image1 = np.array(Image.open('image.jpg'))
print(image1.shape)
# Out:
# (136, 205, 3)

# %%
rows, col, channel = image1.shape
plt.imshow(image1);

# %%
image1_reshaped=image1.reshape(-1,3)
print(image1_reshaped.shape)
# Out:
# (27880, 3)

# %%
print(image1_reshaped)
# Out:
# [[124 166 208]
#  [123 165 205]
#  [124 163 202]
#  ...
#  [ 50  38  26]
#  [ 33  36  25]
#  [ 22  38  35]]

# %% [markdown]
# ## For k=2

# %%
p1=np.random.randint(0,255,(1,3))
p2=np.random.randint(0,255,(1,3))
p1_cluster=p2_cluster=np.empty((0,3))
p1_old=p2_old=np.zeros((2,1))
epoch=0
flag="true"
print(p1)
print(p2)
image1_k=np.copy(image1_reshaped)
while flag=="true":
    i=0
    if np.allclose(p1_old,p1,rtol=0.0001,atol=0,equal_nan=True) and np.allclose(p2_old,p2,rtol=0.0001,atol=0,equal_nan=True):
        flag="false"
    else:
        p1_old,p2_old=p1,p2
        epoch+=1
        print("\nepoch ",epoch,":\n")
        for row in image1_reshaped:
            diff_p1=abs(np.sum(row-p1))
            diff_p2=abs(np.sum(row-p2))
            #print(diff_p1, diff_p2)
            if diff_p1<diff_p2:
                image1_k[i]=p1
                p1_cluster=np.vstack((p1_cluster,row))
            else:
                image1_k[i]=p2
                p2_cluster=np.vstack((p2_cluster,row))
            i+=1
        p1=np.mean(p1_cluster, axis=0)
        p2=np.mean(p2_cluster, axis=0)
        print(p1)
        print(p2)
# Out:
# [[ 78  55 252]]
# [[128   0  31]]
#
# epoch  1 :
#
# [145.68698528 161.39499626 152.03674819]
# [48.15558556 62.31673979 71.06336483]
#
# epoch  2 :
#
# [151.81366351 167.83916035 159.00716007]
# [54.00291201 68.02429135 73.9298168 ]
#
# epoch  3 :
#
# [155.50438356 171.7030137  163.29940224]
# [56.88507703 70.87548862 75.43787077]
#
# epoch  4 :
#
# [158.05345555 174.34672817 166.20332656]
# [58.59561601 72.59248459 76.42529326]
#
# epoch  5 :
#
# [159.94523559 176.29572456 168.36838277]
# [59.76711163 73.78022828 77.11781776]
#
# epoch  6 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-087aa500fd5a> in <module>
#      22             if diff_p1<diff_p2:
#      23                 image1_k[i]=p1
# ---> 24                 p1_cluster=np.vstack((p1_cluster,row))
#      25             else:
#      26                 image1_k[i]=p2
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
image1_k=image1_k.reshape(image1.shape)
plt.imshow(image1_k)
plt.show()

# %% [markdown]
# ## For k=5

# %%
p1=np.random.randint(0,255,(1,3))
p2=np.random.randint(0,255,(1,3))
p3=np.random.randint(0,255,(1,3))
p4=np.random.randint(0,255,(1,3))
p5=np.random.randint(0,255,(1,3))
p1_cluster=p2_cluster=p3_cluster=p4_cluster=p5_cluster=np.empty((0,3))

epoch=0
flag="true"
print(p1)
print(p2)
print(p3)
print(p4)
print(p5)

image1_k=np.copy(image1_reshaped)
while flag=="true":
    if np.allclose(p1_old,p1,rtol=0.0001,atol=0,equal_nan=True) and \
    np.allclose(p2_old,p2,rtol=0.0001,atol=0,equal_nan=True) and \
    np.allclose(p3_old,p3,rtol=0.0001,atol=0,equal_nan=True) and \
    np.allclose(p4_old,p4,rtol=0.0001,atol=0,equal_nan=True) and \
    np.allclose(p5_old,p5,rtol=0.0001,atol=0,equal_nan=True):
        flag="false"
    else:
        p1_old,p2_old,p3_old,p4_old,p5_old=p1,p2,p3,p4,p5
        epoch+=1
        print("\nepoch ",epoch,":\n")
        for j,row in enumerate(image1_reshaped):
            diff_p1=abs(np.sum(row-p1))
            diff_p2=abs(np.sum(row-p2))
            diff_p3=abs(np.sum(row-p3))
            diff_p4=abs(np.sum(row-p4))
            diff_p5=abs(np.sum(row-p5))
            
            if min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p1:
                image1_k[j]=p1
                p1_cluster=np.vstack((p1_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p2:
                image1_k[j]=p2
                p2_cluster=np.vstack((p2_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p3:
                image1_k[j]=p3
                p3_cluster=np.vstack((p3_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p4:
                image1_k[j]=p4
                p4_cluster=np.vstack((p4_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p5:
                image1_k[j]=p5
                p5_cluster=np.vstack((p5_cluster,row))
            i+=1
        p1,p2,p3,p4,p5=np.mean(p1_cluster, axis=0),np.mean(p2_cluster, axis=0),np.mean(p3_cluster, axis=0),np.mean(p4_cluster, axis=0),np.mean(p5_cluster, axis=0)
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
# Out:
# [[ 50 189  65]]
# [[ 39 217  40]]
# [[193 149  11]]
# [[  8 246  32]]
# [[  8 204 204]]
#
# epoch  1 :
#
# [101.11338661 114.26223776  98.10889111]
# [ 97.15409836 107.54262295  90.22786885]
# [111.90559943 130.03517588 112.63747308]
# [52.06728802 66.3177995  73.29711298]
# [177.19084545 193.17059774 188.10177706]
#
# epoch  2 :
#
# [101.92383107 115.48466566  98.84866767]
# [82.31068147 98.59666922 94.84800919]
# [120.38461538 137.96233148 116.81549035]
# [48.3143986  61.84227392 69.66404741]
# [182.87355046 198.851283   197.30428078]
#
# epoch  3 :
#
# [102.43250382 115.95440011  99.49409148]
# [78.42033573 95.40517986 94.85976019]
# [124.11435603 141.77973749 119.55816243]
# [46.17119861 59.2630347  67.26380427]
# [185.91605582 201.85109953 202.13666873]
#
# epoch  4 :
#
# [102.75659528 116.22952477  99.8026473 ]
# [76.29761157 93.57536141 94.77215588]
# [126.38145315 144.10719407 121.28148901]
# [44.74916884 57.55899954 65.59874175]
# [187.81566469 203.71622884 205.16959125]
#
# epoch  5 :
#
# [102.86803224 116.47152451 100.1014775 ]
# [74.93199238 92.38658429 94.62972082]
# [128.06924126 145.77360177 122.68625053]
# [43.72983552 56.32395782 64.37052168]
# [189.21860971 205.07571988 207.31843527]
#
# epoch  6 :
#
# [102.97666247 116.62764842 100.2894378 ]
# [73.93420088 91.5108871  94.49849707]
# [129.29522813 147.03585688 123.86738768]
# [42.95014484 55.37020499 63.39819547]
# [190.31667399 206.1225756  208.92302995]
#
# epoch  7 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-1048d43a8568> in <module>
#      47             elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5)==diff_p5:
#      48                 image1_k[j]=p5
# ---> 49                 p5_cluster=np.vstack((p5_cluster,row))
#      50             i+=1
#      51         p1,p2,p3,p4,p5=np.mean(p1_cluster, axis=0),np.mean(p2_cluster, axis=0),np.mean(p3_cluster, axis=0),np.mean(p4_cluster, axis=0),np.mean(p5_cluster, axis=0)
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
image1_k
# Out:
# array([[129, 147, 123],
#        [129, 147, 123],
#        [129, 147, 123],
#        ...,
#        [ 43,  56,  64],
#        [ 43,  56,  64],
#        [ 43,  56,  64]], dtype=uint8)

# %%
image1_k=image1_k.reshape(image1.shape)
plt.imshow(image1_k)
plt.show()

# %% [markdown]
# ## For k=10

# %%
image1 = np.array(Image.open('image.jpg'))
image1_reshaped=image1.reshape(-1,3)

p1=np.random.randint(0,255,(1,3))
p2=np.random.randint(0,255,(1,3))
p3=np.random.randint(0,255,(1,3))
p4=np.random.randint(0,255,(1,3))
p5=np.random.randint(0,255,(1,3))
p6=np.random.randint(0,255,(1,3))
p7=np.random.randint(0,255,(1,3))
p8=np.random.randint(0,255,(1,3))
p9=np.random.randint(0,255,(1,3))
p10=np.random.randint(0,255,(1,3))

p1_cluster=p2_cluster=p3_cluster=p4_cluster=p5_cluster=p6_cluster=p7_cluster=p8_cluster=p9_cluster=p10_cluster=np.empty((0,3))

epoch=0
flag="true"
print(p1)
print(p2)
print(p3)
print(p4)
print(p5)
print(p6)
print(p7)
print(p8)
print(p9)
print(p10)

image1_k=np.copy(image1_reshaped)

while flag=="true":
    if np.allclose(p1_old,p1,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p2_old,p2,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p3_old,p3,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p4_old,p4,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p5_old,p5,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p6_old,p6,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p7_old,p7,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p8_old,p8,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p9_old,p9,rtol=0.001,atol=0,equal_nan=True) and \
    np.allclose(p10_old,p10,rtol=0.001,atol=0,equal_nan=True):
        flag="false"
    else:
        p1_old,p2_old,p3_old,p4_old,p5_old,p6_old,p7_old,p8_old,p9_old,p10_old=p1,p2,p3,p4,p5,p6,p7,p8,p9,p10
        epoch+=1
        print("\nepoch ",epoch,":\n")
        
        for m,row in enumerate(image1_reshaped):
            diff_p1=abs(np.sum(row-p1))
            diff_p2=abs(np.sum(row-p2))
            diff_p3=abs(np.sum(row-p3))
            diff_p4=abs(np.sum(row-p4))
            diff_p5=abs(np.sum(row-p5))
            diff_p6=abs(np.sum(row-p6))
            diff_p7=abs(np.sum(row-p7))
            diff_p8=abs(np.sum(row-p8))
            diff_p9=abs(np.sum(row-p9))
            diff_p10=abs(np.sum(row-p10))
            
            if min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p1:
                image1_k[m]=p1
                p1_cluster=np.vstack((p1_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p2:
                image1_k[m]=p2
                p2_cluster=np.vstack((p2_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p3:
                image1_k[m]=p3
                p3_cluster=np.vstack((p3_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p4:
                image1_k[m]=p4
                p4_cluster=np.vstack((p4_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p5:
                image1_k[m]=p5
                p5_cluster=np.vstack((p5_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p6:
                image1_k[m]=p6
                p6_cluster=np.vstack((p6_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p7:
                image1_k[m]=p7
                p7_cluster=np.vstack((p7_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p8:
                image1_k[m]=p8
                p8_cluster=np.vstack((p8_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p9:
                image1_k[m]=p9
                p9_cluster=np.vstack((p9_cluster,row))
            elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p10:
                image1_k[m]=p10
                p10_cluster=np.vstack((p10_cluster,row))
                
        p1=np.mean(p1_cluster, axis=0)
        p2=np.mean(p2_cluster, axis=0)
        p3=np.mean(p3_cluster, axis=0)
        p4=np.mean(p4_cluster, axis=0)
        p5=np.mean(p5_cluster, axis=0)
        p6=np.mean(p6_cluster, axis=0)
        p7=np.mean(p7_cluster, axis=0)
        p8=np.mean(p8_cluster, axis=0)
        p9=np.mean(p9_cluster, axis=0)
        p10=np.mean(p10_cluster, axis=0)
        print(p1)
        print(p2)
        print(p3)
        print(p4)
        print(p5)
        print(p6)
        print(p7)
        print(p8)
        print(p9)
        print(p10)
# Out:
# [[112 160  61]]
# [[ 90 131 169]]
# [[131  23  67]]
# [[ 49 163 173]]
# [[226  88 195]]
# [[ 58 123 134]]
# [[227  75   1]]
# [[251 250 152]]
# [[232 108 121]]
# [[126 121 235]]
#
# epoch  1 :
#
# [108.20991401 123.89428427 108.14415781]
# [134.25944767 149.98401163 121.87718023]
# [46.47517986 60.19091727 69.21115108]
# [116.68661417 137.78740157 118.67401575]
# [159.97331524 185.94663048 191.07688829]
# [101.33333333 115.15298886  99.6443769 ]
# [ 88.30573625 103.1794796   93.8693081 ]
# [216.75       226.43918919 232.95400208]
# [147.27464195 164.01769166 135.73041281]
# [154.99425287 172.45785441 156.00574713]
#
# epoch  2 :
#
# [108.33600229 124.16499857 108.36431227]
# [134.90171258 150.3644825  121.78927774]
# [44.07070502 57.00855956 65.81356361]
# [116.78337531 137.75314861 118.43073048]
# [163.79573827 188.93564356 194.6980198 ]
# [101.20610425 114.81652949  98.69513032]
# [80.92683492 97.37207687 94.57976383]
# [219.84418703 228.61392852 234.84333945]
# [147.14452949 163.8194507  135.26969833]
# [152.83719434 172.75160875 161.72844273]
#
# epoch  3 :
#
# [108.29791009 124.22456625 108.44380915]
# [135.21522509 150.59155286 121.75518462]
# [42.61242979 55.20496467 63.82663526]
# [116.90531178 137.77898383 118.39515012]
# [166.03944578 190.56439983 196.53343701]
# [101.00132853 114.07838299  97.61947239]
# [77.49774457 94.44431914 94.54271215]
# [221.5606868  229.82879416 235.88809947]
# [147.08988077 163.75695506 135.1971874 ]
# [152.09767611 173.24981845 164.61147422]
#
# epoch  4 :
#
# [108.32948661 124.21452878 108.44725551]
# [135.37648411 150.70834929 121.73764841]
# [41.66974333 53.99940176 62.48238042]
# [116.98680377 137.85347044 118.4193659 ]
# [167.53472442 191.65823585 197.8051428 ]
# [100.55692975 113.41603978  97.07637384]
# [75.39037082 92.68793574 94.39618066]
# [222.72253629 230.64285714 236.5855615 ]
# [147.04307974 163.75549954 135.35976169]
# [151.93782641 173.74061179 166.35438946]
#
# epoch  5 :
#
# [108.34844897 124.20850107 108.44932512]
# [135.47473035 150.77950693 121.72696456]
# [40.9527271  53.11274221 61.50291473]
# [117.03487738 137.89741144 118.43365123]
# [168.6646485  192.4709889  198.78708375]
# [100.12781601 112.90281836  96.78263738]
# [73.96604841 91.4332757  94.17643823]
# [152.44850857 177.70572615 177.74677555]
#
# epoch  34 :
#
# [107.24390863 123.07635115 107.54060914]
# [136.48455833 151.55522589 121.77918633]
# [36.2463309  47.20192461 54.70938703]
# [117.4754385  137.88318012 118.23670408]
# [178.52295668 199.28253626 206.69342905]
# [ 95.32798769 108.45081789  94.5335133 ]
# [65.10179885 82.99125689 91.7382248 ]
# [231.0017941  236.61408541 241.33516553]
# [147.9234996  164.87873846 137.82399137]
# [152.47881233 177.76648198 177.88098226]
#
# epoch  35 :
#
# [107.21727681 123.05705397 107.5194762 ]
# [136.49818951 151.56912573 121.78343949]
# [36.1958315  47.13195075 54.62375814]
# [117.48115995 137.87384643 118.2267919 ]
# [178.65405721 199.37102284 206.7993477 ]
# [ 95.25036088 108.38569627  94.51832733]
# [64.99752604 82.8888951  91.69581407]
# [231.10139957 236.68737265 241.39117945]
# [147.94485026 164.90112004 137.87401997]
# [152.50717596 177.82334803 178.00659665]
#
# epoch  36 :
#
# [107.19418619 123.0312706  107.48510089]
# [136.5110386  151.58222806 121.78744862]
# [36.14784837 47.06546354 54.54239596]
# [117.48654967 137.86505393 118.21745444]
# [178.78423136 199.45895246 206.90457344]
# [ 95.15403817 108.31319265  94.5055766 ]
# [64.89529279 82.78599789 91.65426819]
# [231.20263858 236.76185461 241.44782019]
# [147.96497493 164.92221644 137.92117586]
# [152.53377999 177.87668628 178.12441829]
#
# epoch  37 :
#
# [107.17247946 123.00703248 107.45278579]
# [136.52317103 151.5945996  121.79123414]
# [36.10219804 47.00220873 54.46498935]
# [117.49163569 137.85675685 118.20864312]
# [178.90736716 199.54212784 207.00410976]
# [ 95.06353335 108.24506825  94.49359602]
# [64.79860771 82.68868487 91.61497699]
# [231.29898174 236.83273467 241.50172182]
# [147.98397627 164.94213527 137.96569957]
# [152.55878324 177.92681513 178.23515051]
#
# epoch  38 :
#
# [107.15203582 122.98420476 107.42235106]
# [136.53464513 151.60629984 121.79481425]
# [36.0587144  46.94195618 54.39125669]
# [117.49644298 137.84891448 118.20031469]
# [179.02648172 199.62291792 207.10202314]
# [ 94.97833478 108.18093794  94.48231785]
# [64.70703107 82.59651347 91.57776177]
# [231.39077582 236.90026795 241.55307835]
# [148.00194579 164.96097245 138.00780551]
# [152.58706324 177.97792739 178.34310551]
#
# epoch  39 :
#
# [107.13274813 122.9626678  107.39363723]
# [136.54551307 151.61738197 121.79820523]
# [36.01724679 46.88449711 54.32094247]
# [117.50099384 137.84149044 118.19243051]
# [179.13953215 199.69959499 207.19495175]
# [ 94.89798909 108.12046047  94.47168208]
# [64.62016843 82.50908668 91.54246225]
# [231.47833557 236.96468603 241.60206588]
# [148.01896529 164.97881374 138.04768541]
# [152.6137214  178.02610841 178.44486938]
#
# epoch  40 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-302494a9c4c1> in <module>
#      79             elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p7:
#      80                 image1_k[m]=p7
# ---> 81                 p7_cluster=np.vstack((p7_cluster,row))
#      82             elif min(diff_p1,diff_p2,diff_p3,diff_p4,diff_p5,diff_p6,diff_p7,diff_p8,diff_p9,diff_p10)==diff_p8:
#      83                 image1_k[m]=p8
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
image1_k=image1_k.reshape(image1.shape)
plt.imshow(image1_k)
plt.show()
